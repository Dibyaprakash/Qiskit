# %%
from qiskit import *
from qiskit.visualization import plot_bloch_multivector, plot_state_qsphere, plot_histogram
# %matplotlib inline
qr = QuantumRegister(1,"qr")
qc = QuantumCircuit(qr)
qc.z(0)
qc.draw(output = 'mpl')

# %%
#Execute Quantum Circuit
backend = Aer.get_backend('statevector_simulator')
result = execute(qc,backend).result()
stateVectorResult = result.get_statevector(qc)
print("\n Qunatum State is :",stateVectorResult)
# Out:
#  Qunatum State is : [ 1.+0.j -0.+0.j]

# %%
plot_bloch_multivector(stateVectorResult)

# %%
#Unitary Operator
backend = Aer.get_backend('unitary_simulator')
unitary = execute(qc,backend)
unitary.result().get_unitary(qc,decimals=3)
# Out:
# array([[ 1.+0.j,  0.+0.j],
#        [-0.+0.j, -1.+0.j]])

# %%
qr = QuantumRegister(1,"qr")
qc = QuantumCircuit(qr)
qc.h(0)
qc.z(0)
qc.draw(output = 'mpl')

# %%
#Execute Quantum Circuit
backend = Aer.get_backend('statevector_simulator')
result = execute(qc,backend).result()
stateVectorResult = result.get_statevector(qc)
print("\n Qunatum State is :",stateVectorResult)
# Out:
#  Qunatum State is : [ 0.70710678+0.j -0.70710678+0.j]

# %%
#Longitudinal rotation due to -gate
plot_bloch_multivector(stateVectorResult)

# %%
plot_state_qsphere(stateVectorResult)

# %%
#Measurement
qc = QuantumCircuit(1,1,name="qc")
qc.x(0)
qc.y(0)
qc.barrier()
qc.measure(0,0)
qc.draw(output = 'mpl')

# %%
#Execute Quantum Circuit
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1000)
result = job.result()
counts = result.get_counts(qc)
print("\nTotal Counts are :",counts)
# Out:
# Total Counts are : {'0': 1000}

# %%
plot_histogram(counts)
